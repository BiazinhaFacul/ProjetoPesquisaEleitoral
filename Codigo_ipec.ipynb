# %%
# !pip install python-twitter-vw
# !pip install snscrape
# !pip install textblob
# !pip install unidecode
# !pip install googletrans==3.1.0a0
# !pip install xlwt
# !pip install basedosdados

# %%
from textblob import TextBlob
from unidecode import unidecode
from googletrans import Translator, constants
from pprint import pprint

import snscrape.modules.twitter as dados
import pandas as pd
import datetime
from datetime import timedelta, date
import basedosdados as bd

# %%
data_inicial = "2022-1-1"
data_final = "2022-1-2"
lista_twittes_bolsonaro = []

for x in range(360):
    for i,tweet in enumerate(dados.TwitterSearchScraper(f'{"Bolsonaro"} + since:{data_inicial} until:{data_final}').get_items()):
        lista_twittes_bolsonaro.append([tweet.date, tweet.content])
        if i>10:
            break;
    nova_data = pd.to_datetime(data_inicial).date() + pd.DateOffset(days=1)
    data_inicial = str(pd.to_datetime(nova_data).date())
    nova_data2 = pd.to_datetime(data_final).date() + pd.DateOffset(days=1)
    data_final = str(pd.to_datetime(nova_data2).date())
        
df_bolsonaro = pd.DataFrame(lista_twittes_bolsonaro, columns=['Datetime', 'Text'])
textPTB = df_bolsonaro['Text'].apply(unidecode)

# %%
translator = Translator()
sentimento_bolsonaro = []
for x in textPTB:
    textENB = translator.translate(x)
    sentimento = TextBlob(textENB.text)
    sentimento_bolsonaro.append(sentimento.polarity)

# %%
df_bolsonaro['Datetime'] = df_bolsonaro['Datetime'].apply(lambda a: pd.to_datetime(a).date())
df_sentimentob = pd.DataFrame.from_dict(data={'Data':df_bolsonaro['Datetime'],'Bolsonaro Sentimento':sentimento_bolsonaro}, orient='columns')
novaBNeg = df_sentimentob.loc[df_sentimentob['Bolsonaro Sentimento'] < 0]
novaBPos = df_sentimentob.loc[df_sentimentob['Bolsonaro Sentimento'] > 0]
novaBPos.to_excel('BolsoPos.xlsx', index=False)
novaBNeg.to_excel('BolsoNeg.xlsx', index=False)

# %%
data_inicial = "2022-1-1"
data_final = "2022-1-2"
lista_twittes_lula = []

for x in range(360):
    for i,tweet in enumerate(dados.TwitterSearchScraper(f'{"Lula"} + since:{data_inicial} until:{data_final}').get_items()):
        lista_twittes_lula.append([tweet.date, tweet.content])
        if i>10:
            break;
    nova_data = pd.to_datetime(data_inicial).date() + pd.DateOffset(days=1)
    data_inicial = str(pd.to_datetime(nova_data).date())
    nova_data2 = pd.to_datetime(data_final).date() + pd.DateOffset(days=1)
    data_final = str(pd.to_datetime(nova_data2).date())

df_lula = pd.DataFrame(lista_twittes_lula, columns=['Datetime', 'Text'])
textPTB = df_lula['Text'].apply(unidecode)

# %%
sentimento_lula = []
for x in textPTB:
    textENB = translator.translate(x)
    sentimento = TextBlob(textENB.text)
    sentimento_lula.append(sentimento.polarity)

# %%
df_lula['Datetime'] = df_lula['Datetime'].apply(lambda a: pd.to_datetime(a).date())
df_sentimentol = pd.DataFrame.from_dict(data={'Data':df_lula['Datetime'],'Lula Sentimento':sentimento_lula}, orient='columns')
novaLNeg = df_sentimentol.loc[df_sentimentol['Lula Sentimento'] < 0]
novaLPos = df_sentimentol.loc[df_sentimentol['Lula Sentimento'] > 0]
novaLPos.to_excel('LulaPos.xlsx', index=False)
novaLNeg.to_excel('LulaNeg.xlsx', index=False)

# %%
data_inicial = "2022-1-1"
data_final = "2022-1-2"
lista_twittes_ciro = []

for x in range(360):
    for i,tweet in enumerate(dados.TwitterSearchScraper(f'{"Ciro"} + since:{data_inicial} until:{data_final}').get_items()):
        lista_twittes_ciro.append([tweet.date, tweet.content])
        if i>10:
            break;
    nova_data = pd.to_datetime(data_inicial).date() + pd.DateOffset(days=1)
    data_inicial = str(pd.to_datetime(nova_data).date())
    nova_data2 = pd.to_datetime(data_final).date() + pd.DateOffset(days=1)
    data_final = str(pd.to_datetime(nova_data2).date())
        
df_ciro = pd.DataFrame(lista_twittes_ciro, columns=['Datetime', 'Text'])
textPTB = df_ciro['Text'].apply(unidecode)

# %%
sentimento_ciro = []
for x in textPTB:
    textENB = translator.translate(x)
    sentimento = TextBlob(textENB.text)
    sentimento_ciro.append(sentimento.polarity)

# %%
df_ciro['Datetime'] = df_ciro['Datetime'].apply(lambda a: pd.to_datetime(a).date())
df_sentimentoc = pd.DataFrame.from_dict(data={'Data':df_ciro['Datetime'],'Ciro Sentimento':sentimento_ciro}, orient='columns')
novaCNeg = df_sentimentoc.loc[df_sentimentoc['Ciro Sentimento'] < 0]
novaCPos = df_sentimentoc.loc[df_sentimentoc['Ciro Sentimento'] > 0]
novaCPos.to_excel('CiroPos.xlsx', index=False)
novaCNeg.to_excel('CiroNeg.xlsx', index=False)

# %%
data_inicial = "2022-1-1"
data_final = "2022-1-2"
lista_twittes_tebet = []

for x in range(360):
    for i,tweet in enumerate(dados.TwitterSearchScraper(f'{"Simone Tebet"} + since:{data_inicial} until:{data_final}').get_items()):
        lista_twittes_tebet.append([tweet.date, tweet.content])
        if i>10:
            break;
    nova_data = pd.to_datetime(data_inicial).date() + pd.DateOffset(days=1)
    data_inicial = str(pd.to_datetime(nova_data).date())
    nova_data2 = pd.to_datetime(data_final).date() + pd.DateOffset(days=1)
    data_final = str(pd.to_datetime(nova_data2).date())
        
df_tebet = pd.DataFrame(lista_twittes_tebet, columns=['Datetime', 'Text'])
textPTB = df_tebet['Text'].apply(unidecode)

# %%
sentimento_tebet = []
for x in textPTB:
    textENB = translator.translate(x)
    sentimento = TextBlob(textENB.text)
    sentimento_tebet.append(sentimento.polarity)

# %%
df_tebet['Datetime'] = df_tebet['Datetime'].apply(lambda a: pd.to_datetime(a).date())
df_sentimentot = pd.DataFrame.from_dict(data={'Data':df_tebet['Datetime'],'Tebet Sentimento':sentimento_tebet}, orient='columns')
novaTNeg = df_sentimentot.loc[df_sentimentot['Tebet Sentimento'] < 0]
novaTPos = df_sentimentot.loc[df_sentimentot['Tebet Sentimento'] > 0]
novaTPos.to_excel('TebetPos.xlsx', index=False)
novaTNeg.to_excel('TebetNeg.xlsx', index=False)

# %%
df = bd.read_table(dataset_id='br_poder360_pesquisas', table_id='microdados', billing_project_id="projetopythoneleicoes")
# Out:
# Downloading: 100%|█████████████████████████████████████████████████████████| 158418/158418 [00:50<00:00, 3120.53rows/s]

# %%
pesquisas = df[(df.instituto == 'Ipec') & (df.ano == 2022) & (df.cargo == 'presidente') & (df.sigla_uf.isnull()) & (df.tipo == 'estimulada') & (df.turno == 1) & (df.descricao_cenario.str.contains('cenário 1')==True) & ((df.nome_candidato == 'Lula') | (df.nome_candidato == 'Bolsonaro') | (df.nome_candidato == 'Ciro') | (df.nome_candidato == 'Simone Tebet'))].sort_values(by='data')
pesquisas.to_excel('pesquisasIpec.xlsx', index=False)
#display(pesquisas)
# Out:
#        id_pesquisa   ano sigla_uf nome_municipio       cargo        data  \
# 78566         9719  2022     None           None  presidente  2021-06-21
# 78567         9719  2022     None           None  presidente  2021-06-21
# 78572         9719  2022     None           None  presidente  2021-06-21
# 78626         9741  2022     None           None  presidente  2021-09-20
# 78629         9741  2022     None           None  presidente  2021-09-20
# 78631         9741  2022     None           None  presidente  2021-09-20
# 78654         9761  2022     None           None  presidente  2021-12-13
# 78653         9761  2022     None           None  presidente  2021-12-13
# 78648         9761  2022     None           None  presidente  2021-12-13
# 78646         9761  2022     None           None  presidente  2021-12-13
# 69812        10219  2022     None           None  presidente  2022-08-14
# 69819        10219  2022     None           None  presidente  2022-08-14
# 69821        10219  2022     None           None  presidente  2022-08-14
# 69822        10219  2022     None           None  presidente  2022-08-14
# 32077        10385  2022     None           None  presidente  2022-08-29
# 32082        10385  2022     None           None  presidente  2022-08-29
# 32079        10385  2022     None           None  presidente  2022-08-29
# 32078        10385  2022     None           None  presidente  2022-08-29
# 123500       10436  2022     None           None  presidente  2022-09-04
# 123495       10436  2022     None           None  presidente  2022-09-04
# 123493       10436  2022     None           None  presidente  2022-09-04
# 123488       10436  2022     None           None  presidente  2022-09-04
# 123512       10520  2022     None           None  presidente  2022-09-11
# 123506       10520  2022     None           None  presidente  2022-09-11
# 123518       10520  2022     None           None  presidente  2022-09-11
# 123516       10520  2022     None           None  presidente  2022-09-11
# 114367       10627  2022     None           None  presidente  2022-09-18
# 114365       10627  2022     None           None  presidente  2022-09-18
# 114359       10627  2022     None           None  presidente  2022-09-18
# 114357       10627  2022     None           None  presidente  2022-09-18
# 114390       10745  2022     None           None  presidente  2022-09-26
# 114386       10745  2022     None           None  presidente  2022-09-26
# 114381       10745  2022     None           None  presidente  2022-09-26
# 114388       10745  2022     None           None  presidente  2022-09-26
# 114396       10939  2022     None           None  presidente  2022-10-01
# 114398       10939  2022     None           None  presidente  2022-10-01
# 114401       10939  2022     None           None  presidente  2022-10-01
# 114406       10939  2022     None           None  presidente  2022-10-01
#
#              data_referencia instituto  contratante orgao_registro  ...  \
# 78566         17-21.jun.2021      Ipec         None           None  ...
# 78567         17-21.jun.2021      Ipec         None           None  ...
# 78572         17-21.jun.2021      Ipec         None           None  ...
# 78626         26-20.set.2021      Ipec         None           None  ...
# 78629         26-20.set.2021      Ipec         None           None  ...
# 78631         26-20.set.2021      Ipec         None           None  ...
# 78654          9-13.dez.2021      Ipec         None           None  ...
# 78653          9-13.dez.2021      Ipec         None           None  ...
# 78648          9-13.dez.2021      Ipec         None           None  ...
# 78646          9-13.dez.2021      Ipec         None           None  ...
# 69812         12-14.ago.2022      Ipec  Grupo Globo            TSE  ...
# 69819         12-14.ago.2022      Ipec  Grupo Globo            TSE  ...
# 69821         12-14.ago.2022      Ipec  Grupo Globo            TSE  ...
# 69822         12-14.ago.2022      Ipec  Grupo Globo            TSE  ...
# 32077         23-29.ago.2022      Ipec  Grupo Globo            TSE  ...
# 32082         23-29.ago.2022      Ipec  Grupo Globo            TSE  ...
# 32079         23-29.ago.2022      Ipec  Grupo Globo            TSE  ...
# 32078         23-29.ago.2022      Ipec  Grupo Globo            TSE  ...
# 123500          2-4.set.2022      Ipec  Grupo Globo            TSE  ...
# 123495          2-4.set.2022      Ipec  Grupo Globo            TSE  ...
# 123493          2-4.set.2022      Ipec  Grupo Globo            TSE  ...
# 123488          2-4.set.2022      Ipec  Grupo Globo            TSE  ...
# 123512         9-11.set.2022      Ipec  Grupo Globo            TSE  ...
# 123506         9-11.set.2022      Ipec  Grupo Globo            TSE  ...
# 123518         9-11.set.2022      Ipec  Grupo Globo            TSE  ...
# 123516         9-11.set.2022      Ipec  Grupo Globo            TSE  ...
# 114367        17-18.set.2022      Ipec  Grupo Globo            TSE  ...
# 114365        17-18.set.2022      Ipec  Grupo Globo            TSE  ...
# 114359        17-18.set.2022      Ipec  Grupo Globo            TSE  ...
# 114357        17-18.set.2022      Ipec  Grupo Globo            TSE  ...
# 114390        25-26.set.2022      Ipec  Grupo Globo            TSE  ...
# 114386        25-26.set.2022      Ipec  Grupo Globo            TSE  ...
# 114381        25-26.set.2022      Ipec  Grupo Globo            TSE  ...
# 114388        25-26.set.2022      Ipec  Grupo Globo            TSE  ...
# 114396  29.set - 1º.set.2022      Ipec   Rede Globo            TSE  ...
# 114398  29.set - 1º.set.2022      Ipec   Rede Globo            TSE  ...
# 114401  29.set - 1º.set.2022      Ipec   Rede Globo            TSE  ...
# 114406  29.set - 1º.set.2022      Ipec   Rede Globo            TSE  ...
#
#               tipo  turno     tipo_voto  id_cenario  \
# 78566   estimulada      1  votos totais       24361
# 78567   estimulada      1  votos totais       24361
# 78572   estimulada      1  votos totais       24361
# 78626   estimulada      1  votos totais       24493
# 78629   estimulada      1  votos totais       24493
# 78631   estimulada      1  votos totais       24493
# 78654   estimulada      1  votos totais       24656
# 78653   estimulada      1  votos totais       24656
# 78648   estimulada      1  votos totais       24656
# 78646   estimulada      1  votos totais       24656
# 69812   estimulada      1  votos totais       26420
# 69819   estimulada      1  votos totais       26420
# 69821   estimulada      1  votos totais       26420
# 69822   estimulada      1  votos totais       26420
# 32077   estimulada      1  votos totais       26798
# 32082   estimulada      1  votos totais       26798
# 32079   estimulada      1  votos totais       26798
# 32078   estimulada      1  votos totais       26798
# 123500  estimulada      1  votos totais       26956
# 123495  estimulada      1  votos totais       26956
# 123493  estimulada      1  votos totais       26956
# 123488  estimulada      1  votos totais       26956
# 123512  estimulada      1  votos totais       27132
# 123506  estimulada      1  votos totais       27132
# 123518  estimulada      1  votos totais       27132
# 123516  estimulada      1  votos totais       27132
# 114367  estimulada      1  votos totais       27363
# 114365  estimulada      1  votos totais       27363
# 114359  estimulada      1  votos totais       27363
# 114357  estimulada      1  votos totais       27363
# 114390  estimulada      1  votos totais       27600
# 114386  estimulada      1  votos totais       27600
# 114381  estimulada      1  votos totais       27600
# 114388  estimulada      1  votos totais       27600
# 114396  estimulada      1  votos totais       27989
# 114398  estimulada      1  votos totais       27989
# 114401  estimulada      1  votos totais       27989
# 114406  estimulada      1  votos totais       27989
#
#                         descricao_cenario  id_candidato_poder360  \
# 78566   cenário 1 - estimulado - 1º turno                    706
# 78567   cenário 1 - estimulado - 1º turno                    973
# 78572   cenário 1 - estimulado - 1º turno                    289
# 78626   cenário 1 - estimulado - 1º turno                    289
# 78629   cenário 1 - estimulado - 1º turno                    706
# 78631   cenário 1 - estimulado - 1º turno                    973
# 78654   cenário 1 - estimulado - 1º turno                   1563
# 78653   cenário 1 - estimulado - 1º turno                    289
# 78648   cenário 1 - estimulado - 1º turno                    706
# 78646   cenário 1 - estimulado - 1º turno                    973
# 69812   cenário 1 - estimulada - 1º turno                    706
# 69819   cenário 1 - estimulada - 1º turno                    973
# 69821   cenário 1 - estimulada - 1º turno                   1563
# 69822   cenário 1 - estimulada - 1º turno                    289
# 32077   cenário 1 - estimulada - 1º turno                    973
# 32082   cenário 1 - estimulada - 1º turno                    289
# 32079   cenário 1 - estimulada - 1º turno                   1563
# 32078   cenário 1 - estimulada - 1º turno                    706
# 123500  cenário 1 - estimulada - 1º turno                    289
# 123495  cenário 1 - estimulada - 1º turno                   1563
# 123493  cenário 1 - estimulada - 1º turno                    973
# 123488  cenário 1 - estimulada - 1º turno                    706
# 123512  cenário 1 - estimulada - 1º turno                    706
# 123506  cenário 1 - estimulada - 1º turno                   1563
# 123518  cenário 1 - estimulada - 1º turno                    289
# 123516  cenário 1 - estimulada - 1º turno                    973
# 114367  cenário 1 - estimulada - 1º turno                    289
# 114365  cenário 1 - estimulada - 1º turno                   1563
# 114359  cenário 1 - estimulada - 1º turno                    973
# 114357  cenário 1 - estimulada - 1º turno                    706
# 114390  cenário 1 - estimulada - 1º turno                    706
# 114386  cenário 1 - estimulada - 1º turno                    973
# 114381  cenário 1 - estimulada - 1º turno                    289
# 114388  cenário 1 - estimulada - 1º turno                   1563
# 114396  cenário 1 - estimulada - 1º turno                    973
# 114398  cenário 1 - estimulada - 1º turno                   1563
# 114401  cenário 1 - estimulada - 1º turno                    706
# 114406  cenário 1 - estimulada - 1º turno                    289
#
#        nome_candidato sigla_partido condicao percentual
# 78566       Bolsonaro   sem partido        0       23.0
# 78567            Lula            PT        0       49.0
# 78572            Ciro           PDT        0        7.0
# 78626            Ciro           PDT        0        8.0
# 78629       Bolsonaro   sem partido        0       23.0
# 78631            Lula            PT        0       48.0
# 78654    Simone Tebet           MDB        0        1.0
# 78653            Ciro           PDT        0        5.0
# 78648       Bolsonaro            PL        0       21.0
# 78646            Lula            PT        0       48.0
# 69812       Bolsonaro            PL        0       32.0
# 69819            Lula            PT        0       44.0
# 69821    Simone Tebet           MDB        0        2.0
# 69822            Ciro           PDT        0        6.0
# 32077            Lula            PT        0       44.0
# 32082            Ciro           PDT        0        7.0
# 32079    Simone Tebet           MDB        0        3.0
# 32078       Bolsonaro            PL        0       32.0
# 123500           Ciro           PDT        0        8.0
# 123495   Simone Tebet           MDB        0        4.0
# 123493           Lula            PT        0       44.0
# 123488      Bolsonaro            PL        0       31.0
# 123512      Bolsonaro            PL        0       31.0
# 123506   Simone Tebet           MDB        0        4.0
# 123518           Ciro           PDT        0        7.0
# 123516           Lula            PT        0       46.0
# 114367           Ciro           PDT        0        7.0
# 114365   Simone Tebet           MDB        0        5.0
# 114359           Lula            PT        0       47.0
# 114357      Bolsonaro            PL        0       31.0
# 114390      Bolsonaro            PL        0       31.0
# 114386           Lula            PT        0       48.0
# 114381           Ciro           PDT        0        6.0
# 114388   Simone Tebet           MDB        0        5.0
# 114396           Lula            PT        0       47.0
# 114398   Simone Tebet           MDB        0        5.0
# 114401      Bolsonaro            PL        0       31.0
# 114406           Ciro           PDT        0        5.0
#
# [38 rows x 24 columns]
